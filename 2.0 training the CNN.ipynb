# %%
import numpy as np

data=np.load('data.npy')
target=np.load('target.npy')

#loading the save numpy arrays in the previous code

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense,Activation,Flatten,Dropout
from tensorflow.keras.layers import Conv2D,MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint

model=Sequential()

model.add(Conv2D(100,(3,3),input_shape=data.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#The first CNN layer followed by Relu and MaxPooling layers

model.add(Conv2D(100,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#The second convolution layer followed by Relu and MaxPooling layers

model.add(Flatten())
model.add(Dropout(0.5))
#Flatten layer to stack the output convolutions from second convolution layer
model.add(Dense(50,activation='relu'))
#Dense layer of 64 neurons
model.add(Dense(2,activation='softmax'))
#The Final layer with two outputs for two categories

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
from sklearn.model_selection import train_test_split

train_data,test_data,train_target,test_target=train_test_split(data,target,test_size=0.1)

# %%
checkpoint = ModelCheckpoint('model-{epoch:03d}.model',monitor='val_loss',verbose=0,save_best_only=True,mode='auto')
history=model.fit(train_data,train_target,epochs=20,callbacks=[checkpoint],validation_split=0.2)
# Out:
# Train on 992 samples, validate on 249 samples
# Epoch 1/20
# 960/992 [============================>.] - ETA: 1s - loss: 0.7083 - accuracy: 0.5354WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: model-001.model\assets
# 992/992 [==============================] - 36s 36ms/sample - loss: 0.7055 - accuracy: 0.5373 - val_loss: 0.6473 - val_accuracy: 0.5422
# Epoch 2/20
# 960/992 [============================>.] - ETA: 1s - loss: 0.5196 - accuracy: 0.7479INFO:tensorflow:Assets written to: model-002.model\assets
# 992/992 [==============================] - 36s 36ms/sample - loss: 0.5163 - accuracy: 0.7480 - val_loss: 0.4768 - val_accuracy: 0.7470
# Epoch 3/20
# 960/992 [============================>.] - ETA: 1s - loss: 0.3626 - accuracy: 0.8438INFO:tensorflow:Assets written to: model-003.model\assets
# 992/992 [==============================] - 35s 36ms/sample - loss: 0.3607 - accuracy: 0.8458 - val_loss: 0.3972 - val_accuracy: 0.8072
# Epoch 4/20
# 960/992 [============================>.] - ETA: 1s - loss: 0.2489 - accuracy: 0.8927INFO:tensorflow:Assets written to: model-004.model\assets
# 992/992 [==============================] - 37s 37ms/sample - loss: 0.2533 - accuracy: 0.8911 - val_loss: 0.2777 - val_accuracy: 0.8876
# Epoch 5/20
# 960/992 [============================>.] - ETA: 1s - loss: 0.1825 - accuracy: 0.9312INFO:tensorflow:Assets written to: model-005.model\assets
# 992/992 [==============================] - 43s 44ms/sample - loss: 0.1821 - accuracy: 0.9315 - val_loss: 0.2164 - val_accuracy: 0.9197
# Epoch 6/20
# 960/992 [============================>.] - ETA: 1s - loss: 0.1269 - accuracy: 0.9552INFO:tensorflow:Assets written to: model-006.model\assets
# 992/992 [==============================] - 38s 39ms/sample - loss: 0.1273 - accuracy: 0.9546 - val_loss: 0.1509 - val_accuracy: 0.9478
# Epoch 7/20
# 992/992 [==============================] - 36s 36ms/sample - loss: 0.0920 - accuracy: 0.9698 - val_loss: 0.2103 - val_accuracy: 0.9116
# Epoch 8/20
# 960/992 [============================>.] - ETA: 1s - loss: 0.0790 - accuracy: 0.9802INFO:tensorflow:Assets written to: model-008.model\assets
# 992/992 [==============================] - 40s 40ms/sample - loss: 0.0781 - accuracy: 0.9808 - val_loss: 0.1237 - val_accuracy: 0.9518
# Epoch 9/20
# 992/992 [==============================] - 40s 41ms/sample - loss: 0.0552 - accuracy: 0.9819 - val_loss: 0.1475 - val_accuracy: 0.9518
# Epoch 10/20
# 960/992 [============================>.] - ETA: 1s - loss: 0.0430 - accuracy: 0.9844INFO:tensorflow:Assets written to: model-010.model\assets
# 992/992 [==============================] - 42s 42ms/sample - loss: 0.0420 - accuracy: 0.9849 - val_loss: 0.1182 - val_accuracy: 0.9639
# Epoch 11/20
# 960/992 [============================>.] - ETA: 1s - loss: 0.0423 - accuracy: 0.9823INFO:tensorflow:Assets written to: model-011.model\assets
# 992/992 [==============================] - 40s 41ms/sample - loss: 0.0429 - accuracy: 0.9819 - val_loss: 0.1062 - val_accuracy: 0.9558
# Epoch 12/20
# 992/992 [==============================] - 36s 37ms/sample - loss: 0.0501 - accuracy: 0.9839 - val_loss: 0.2508 - val_accuracy: 0.9197
# Epoch 13/20
# 992/992 [==============================] - 37s 37ms/sample - loss: 0.0303 - accuracy: 0.9889 - val_loss: 0.1454 - val_accuracy: 0.9518
# Epoch 14/20
# 992/992 [==============================] - 35s 35ms/sample - loss: 0.0229 - accuracy: 0.9929 - val_loss: 0.1904 - val_accuracy: 0.9438
# Epoch 15/20
# 992/992 [==============================] - 35s 36ms/sample - loss: 0.0193 - accuracy: 0.9919 - val_loss: 0.1683 - val_accuracy: 0.9438
# Epoch 16/20
# 992/992 [==============================] - 35s 35ms/sample - loss: 0.0235 - accuracy: 0.9929 - val_loss: 0.1238 - val_accuracy: 0.9598
# Epoch 17/20
# 992/992 [==============================] - 35s 35ms/sample - loss: 0.0290 - accuracy: 0.9869 - val_loss: 0.1065 - val_accuracy: 0.9679
# Epoch 18/20
# 992/992 [==============================] - 35s 36ms/sample - loss: 0.0130 - accuracy: 0.9950 - val_loss: 0.1441 - val_accuracy: 0.9398
# Epoch 19/20
# 992/992 [==============================] - 39s 39ms/sample - loss: 0.0481 - accuracy: 0.9819 - val_loss: 0.2293 - val_accuracy: 0.9317
# Epoch 20/20
# 992/992 [==============================] - 40s 40ms/sample - loss: 0.0230 - accuracy: 0.9929 - val_loss: 0.1615 - val_accuracy: 0.9558

# %%
from matplotlib import pyplot as plt

plt.plot(history.history['loss'],'r',label='training loss')
plt.plot(history.history['val_loss'],label='validation loss')
plt.xlabel('# epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'],'r',label='training accuracy')
plt.plot(history.history['val_accuracy'],label='validation accuracy')
plt.xlabel('# epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
print(model.evaluate(test_data,test_target))
# Out:
# 138/138 [==============================] - 1s 8ms/sample - loss: 0.1790 - accuracy: 0.9565
# [0.17897576242145422, 0.95652175]
